# %%
import tensorflow as tf
from tensorflow.keras.utils import plot_model
import resnet

# %%
ae = resnet.Autoencoder()

plot_model(ae.build_graph())

# %%
en = resnet.Encoder(resnet.Bottleneck, [3, 4, 6, 3])
de = resnet.Decoder()

plot_model(en.build_graph())

# %%
plot_model(de.build_graph())

# %%
en.layers
