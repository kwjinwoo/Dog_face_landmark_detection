# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
from tqdm import tqdm
import numpy as np
import cv2
import mobilenet_ae_Unet
import data_util
import pandas as pd

# %%
mse = keras.losses.MeanSquaredError()
ce = keras.losses.CategoricalCrossentropy()

# %%
def custom_loss(y_true, y_pred):
    y_class_true = y_true[:, 0:133]
    y_class_pred = y_pred[:, 0:133]
    
    y_point_true = y_true[:, 133:]
    y_point_pred = y_pred[:, 133:]
    
    class_loss = ce(y_class_true, y_class_pred)
    point_loss = mse(y_point_true, y_point_pred)
    
    return 0.5 * point_loss + 0.5 * class_loss

# %%
# encoder = tf.keras.applications.mobilenet_v2.MobileNetV2(
#     input_shape=(256,256,3), alpha=1.0, include_top=None, weights='imagenet',
#     pooling=None, classes=1    
# )
encoder = mobilenet_ae_Unet.MobileNetV2_UNet().build_model(20)
encoder.load_weights('trained_ckpt/mobileNetAE_15')
last_layer = encoder.get_layer('encoder_last_layer')#the name of the last layer you want from the model)
last_output = last_layer.output
inputs = encoder.input
encoder = tf.keras.Model(inputs, last_output)
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8A94F6190> and <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x000001D8B5335EE0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B536F610> and <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8A94F6190>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.convolutional.DepthwiseConv2D object at 0x000001D8B536FC70> and <tensorflow.python.keras.layers.advanced_activations.ReLU object at 0x000001D8F4ECE2E0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B5541670> and <tensorflow.python.keras.layers.convolutional.DepthwiseConv2D object at 0x000001D8B536FC70>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B555A9A0> and <tensorflow.python.keras.layers.advanced_activations.ReLU object at 0x000001D8B5541400>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B5563B50> and <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B555A9A0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B5571910> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B5563B50>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B557A760> and <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B5571910>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.convolutional.DepthwiseConv2D object at 0x000001D8B5593790> and <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x000001D8B5587D90>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B55A0C40> and <tensorflow.python.keras.layers.convolutional.DepthwiseConv2D object at 0x000001D8B5593790>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B55ADB50> and <tensorflow.python.keras.layers.advanced_activations.ReLU object at 0x000001D8B55936A0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B55B6C10> and <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B55ADB50>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B55C59A0> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B55B6C10>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B55CD7F0> and <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B55C59A0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.convolutional.DepthwiseConv2D object at 0x000001D8B55DCFA0> and <tensorflow.python.keras.layers.advanced_activations.ReLU object at 0x000001D8B55CD910>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B55E5910> and <tensorflow.python.keras.layers.convolutional.DepthwiseConv2D object at 0x000001D8B55DCFA0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B55FFC70> and <tensorflow.python.keras.layers.advanced_activations.ReLU object at 0x000001D8B55F5490>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B5606BE0> and <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B55FFC70>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B5616BB0> and <tensorflow.python.keras.layers.merge.Add object at 0x000001D8B5606AC0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B5626F10> and <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B5616BB0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.convolutional.DepthwiseConv2D object at 0x000001D8B5639850> and <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x000001D8B562EE50>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B563E430> and <tensorflow.python.keras.layers.convolutional.DepthwiseConv2D object at 0x000001D8B5639850>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B5654C10> and <tensorflow.python.keras.layers.advanced_activations.ReLU object at 0x000001D8B5639760>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B565DCD0> and <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B5654C10>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B5668A60> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B565DCD0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B56728B0> and <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B5668A60>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.convolutional.DepthwiseConv2D object at 0x000001D8B5681F40> and <tensorflow.python.keras.layers.advanced_activations.ReLU object at 0x000001D8B5672610>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B5691910> and <tensorflow.python.keras.layers.convolutional.DepthwiseConv2D object at 0x000001D8B5681F40>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B56A6D00> and <tensorflow.python.keras.layers.advanced_activations.ReLU object at 0x000001D8B5699AF0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B56ADC70> and <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B56A6D00>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B56BFC40> and <tensorflow.python.keras.layers.merge.Add object at 0x000001D8B56ADB50>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B6B6BEE0> and <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B56BFC40>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.convolutional.DepthwiseConv2D object at 0x000001D8B6B77F40> and <tensorflow.python.keras.layers.advanced_activations.ReLU object at 0x000001D8B6B6BEB0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B6B84910> and <tensorflow.python.keras.layers.convolutional.DepthwiseConv2D object at 0x000001D8B6B77F40>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B6B9BD00> and <tensorflow.python.keras.layers.advanced_activations.ReLU object at 0x000001D8B6B8EAF0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B6BA1C70> and <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B6B9BD00>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B6BB2C40> and <tensorflow.python.keras.layers.merge.Add object at 0x000001D8B6BA1B50>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B6BBEEE0> and <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B6BB2C40>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.convolutional.DepthwiseConv2D object at 0x000001D8B6BD38E0> and <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x000001D8B6BC9E20>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B6BE1D90> and <tensorflow.python.keras.layers.convolutional.DepthwiseConv2D object at 0x000001D8B6BD38E0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B6BEFCA0> and <tensorflow.python.keras.layers.advanced_activations.ReLU object at 0x000001D8B6BD37F0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B6BF8D60> and <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B6BEFCA0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B6C01AF0> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B6BF8D60>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B6C0D940> and <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B6C01AF0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.convolutional.DepthwiseConv2D object at 0x000001D8B6C1CF70> and <tensorflow.python.keras.layers.advanced_activations.ReLU object at 0x000001D8B6C0D6A0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B6C28A30> and <tensorflow.python.keras.layers.convolutional.DepthwiseConv2D object at 0x000001D8B6C1CF70>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B6C3FD90> and <tensorflow.python.keras.layers.advanced_activations.ReLU object at 0x000001D8B6C345B0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B6C4BA90> and <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B6C3FD90>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B6C58CD0> and <tensorflow.python.keras.layers.merge.Add object at 0x000001D8B6C4BE80>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B6C65E80> and <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B6C58CD0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.convolutional.DepthwiseConv2D object at 0x000001D8B6C6FF70> and <tensorflow.python.keras.layers.advanced_activations.ReLU object at 0x000001D8B6C65F70>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B6C7AA30> and <tensorflow.python.keras.layers.convolutional.DepthwiseConv2D object at 0x000001D8B6C6FF70>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B6C93D90> and <tensorflow.python.keras.layers.advanced_activations.ReLU object at 0x000001D8B6C8A5B0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B6CA0A90> and <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B6C93D90>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B6CADCD0> and <tensorflow.python.keras.layers.merge.Add object at 0x000001D8B6CA0E80>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B6CBBE80> and <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B6CADCD0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.convolutional.DepthwiseConv2D object at 0x000001D8B6CC3F70> and <tensorflow.python.keras.layers.advanced_activations.ReLU object at 0x000001D8B6CBBF70>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B6CCCA30> and <tensorflow.python.keras.layers.convolutional.DepthwiseConv2D object at 0x000001D8B6CC3F70>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B6CE7D90> and <tensorflow.python.keras.layers.advanced_activations.ReLU object at 0x000001D8B6CDC5B0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B6CF4A90> and <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B6CE7D90>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B6CFECD0> and <tensorflow.python.keras.layers.merge.Add object at 0x000001D8B6CF4E80>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B6D0CE80> and <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B6CFECD0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.convolutional.DepthwiseConv2D object at 0x000001D8B6D16F70> and <tensorflow.python.keras.layers.advanced_activations.ReLU object at 0x000001D8B6D0CF70>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B6D20A30> and <tensorflow.python.keras.layers.convolutional.DepthwiseConv2D object at 0x000001D8B6D16F70>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B6D3BD90> and <tensorflow.python.keras.layers.advanced_activations.ReLU object at 0x000001D8B6D2E5B0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B6D46A90> and <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B6D3BD90>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B6D537C0> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B6D46A90>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B6D5B640> and <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B6D537C0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.convolutional.DepthwiseConv2D object at 0x000001D8B7D39D90> and <tensorflow.python.keras.layers.advanced_activations.ReLU object at 0x000001D8B7D30EE0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B7D47700> and <tensorflow.python.keras.layers.convolutional.DepthwiseConv2D object at 0x000001D8B7D39D90>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B7D5DA60> and <tensorflow.python.keras.layers.advanced_activations.ReLU object at 0x000001D8B7D55070>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B7D659A0> and <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B7D5DA60>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B7D79910> and <tensorflow.python.keras.layers.merge.Add object at 0x000001D8B7D65DF0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B7D84F10> and <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B7D79910>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.convolutional.DepthwiseConv2D object at 0x000001D8B7D8EDC0> and <tensorflow.python.keras.layers.advanced_activations.ReLU object at 0x000001D8B7D84E80>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B7D96730> and <tensorflow.python.keras.layers.convolutional.DepthwiseConv2D object at 0x000001D8B7D8EDC0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B7DB3A90> and <tensorflow.python.keras.layers.advanced_activations.ReLU object at 0x000001D8B7DA80D0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B7DB99D0> and <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B7DB3A90>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B7DCE910> and <tensorflow.python.keras.layers.merge.Add object at 0x000001D8B7DB9E20>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B7DD7F10> and <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B7DCE910>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.convolutional.DepthwiseConv2D object at 0x000001D8B7DED670> and <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x000001D8B7DE3C70>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B7DF00D0> and <tensorflow.python.keras.layers.convolutional.DepthwiseConv2D object at 0x000001D8B7DED670>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B7E06910> and <tensorflow.python.keras.layers.advanced_activations.ReLU object at 0x000001D8B7DF9B50>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B7E12D60> and <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B7E06910>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B7E1D880> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B7E12D60>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B7E276D0> and <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B7E1D880>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.convolutional.DepthwiseConv2D object at 0x000001D8B7E35E50> and <tensorflow.python.keras.layers.advanced_activations.ReLU object at 0x000001D8B7E27430>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B7E407C0> and <tensorflow.python.keras.layers.convolutional.DepthwiseConv2D object at 0x000001D8B7E35E50>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B7E56B20> and <tensorflow.python.keras.layers.advanced_activations.ReLU object at 0x000001D8B7E4F340>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B7E5F970> and <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B7E56B20>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B7E72A60> and <tensorflow.python.keras.layers.merge.Add object at 0x000001D8B7E5FEE0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B7E7EDC0> and <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B7E72A60>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.convolutional.DepthwiseConv2D object at 0x000001D8B7E8AE50> and <tensorflow.python.keras.layers.advanced_activations.ReLU object at 0x000001D8B7E7ED60>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B7E937C0> and <tensorflow.python.keras.layers.convolutional.DepthwiseConv2D object at 0x000001D8B7E8AE50>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B7EACB20> and <tensorflow.python.keras.layers.advanced_activations.ReLU object at 0x000001D8B7EA2340>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B7EB3970> and <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B7EACB20>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# ...
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B7F00B20> and <tensorflow.python.keras.layers.advanced_activations.ReLU object at 0x000001D8B7EF5340>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B7F07970> and <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B7F00B20>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B7F3A310> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B7F07970>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B7F33970> and <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B7F3A310>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.convolutional.Conv2DTranspose object at 0x000001D8B7F83520> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B7F33970>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B7F83A60> and <tensorflow.python.keras.layers.convolutional.Conv2DTranspose object at 0x000001D8B7F83520>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.convolutional.Conv2DTranspose object at 0x000001D8B7F92E50> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B7F83A60>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B7FA3D00> and <tensorflow.python.keras.layers.merge.Concatenate object at 0x000001D8B7F92CD0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B80F29D0> and <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B7FA3D00>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B80F9FA0> and <tensorflow.python.keras.layers.core.Dropout object at 0x000001D8B80F9820>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B80FFA60> and <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B80F9FA0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.convolutional.Conv2DTranspose object at 0x000001D8B8120490> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B80FFA60>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B8128550> and <tensorflow.python.keras.layers.merge.Concatenate object at 0x000001D8B812BE80>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B81284F0> and <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B8128550>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B8148130> and <tensorflow.python.keras.layers.core.Dropout object at 0x000001D8B8148190>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B81486A0> and <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B8148130>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.convolutional.Conv2DTranspose object at 0x000001D8B816BB50> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B81486A0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B8178AC0> and <tensorflow.python.keras.layers.merge.Concatenate object at 0x000001D8B816B070>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B81783D0> and <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B8178AC0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B81977F0> and <tensorflow.python.keras.layers.core.Dropout object at 0x000001D8B81975E0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B8197A30> and <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B81977F0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.convolutional.Conv2DTranspose object at 0x000001D8B81BF250> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B8197A30>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B81C7340> and <tensorflow.python.keras.layers.merge.Concatenate object at 0x000001D8B81CBF70>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B81D7F70> and <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B81C7340>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B81E2EE0> and <tensorflow.python.keras.layers.core.Dropout object at 0x000001D8B81E2CD0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B8204EE0> and <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B81E2EE0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.convolutional.Conv2DTranspose object at 0x000001D8B820C940> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B8204EE0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B820CF10> and <tensorflow.python.keras.layers.convolutional.Conv2DTranspose object at 0x000001D8B820C940>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B820C1F0> and <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B820CF10>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B8235250> and <tensorflow.python.keras.layers.core.Dropout object at 0x000001D8B8235040>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B823C250> and <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B8235250>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001D8B82569D0> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x000001D8B823C250>).

# %%
batch_size=16

inputs = keras.layers.Input(shape=(224,224,3))

encoder_output = encoder(inputs)
# flatten = keras.layers.Flatten()(encoder_output)
gap = keras.layers.GlobalAveragePooling2D()(encoder_output)

# branch1_class = keras.layers.Dense(133,activation='softmax',name='branch1_class')(flatten)
branch1_class = keras.layers.Dense(133,activation='softmax',name='branch1_class')(gap)

# branch2_landmark = keras.layers.Dense(16,name='branch2_landmark')(flatten)
branch2_landmark = keras.layers.Dense(16,name='branch2_landmark')(gap)

out= keras.layers.concatenate([branch1_class,branch2_landmark])       # concatnate?

model = keras.models.Model(inputs, out)
model.compile(loss=custom_loss,
            optimizer='adam'
            )
model.summary()
# Out:
# Model: "functional_9"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# functional_7 (Functional)       (None, 8, 8, 1280)   2257984     input_4[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 1280)         0           functional_7[0][0]
# __________________________________________________________________________________________________
# branch1_class (Dense)           (None, 133)          170373      global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# branch2_landmark (Dense)        (None, 16)           20496       global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 149)          0           branch1_class[0][0]
#                                                                  branch2_landmark[0][0]
# ==================================================================================================
# Total params: 2,448,853
# Trainable params: 2,414,741
# Non-trainable params: 34,112
# __________________________________________________________________________________________________

# %%
ds = data_util.get_cu_dataset(train_type='class', batch_size=batch_size)

# %%
for i in ds.take(1):
    print(i[0].shape)
    print(i[1].shape)
# Out:
# (16, 256, 256, 3)
# (16, 149)

# %%
ds_size = len(list(ds))
ds_size
# Out:
# 478

# %%
train_size = int(0.7 * ds_size)
val_size = int(0.15 * ds_size)
test_size = int(0.15 * ds_size)

train_ds = ds.take(train_size)
test_ds = ds.skip(train_size)
val_ds = test_ds.skip(val_size)
test_ds = test_ds.take(test_size)

# %%
len(list(train_ds)), len(list(val_ds)), len(list(test_ds))
# Out:
# (334, 73, 71)

# %%
ckpt_path = 'mobilenetv2_multi'
callbacks_list = [
    # accuracy 기준 가장 높은 모델의 weight 저장
    tf.keras.callbacks.ModelCheckpoint(
        filepath = ckpt_path,
        monitor='val_loss',
        mode='min',
        save_weights_only=True,
        save_best_only=True
    ),
    # EarlyStopping
    # tf.keras.callbacks.EarlyStopping(
    #    monitor='val_loss',
    #    mode='min',
    #    verbose=1, 
    #    patience=20
    # )
]

# %%
hist = model.fit(train_ds, validation_data=val_ds, epochs=100, callbacks=callbacks_list)
# Out:
# Epoch 1/100
#       6/Unknown - 8s 1s/step - loss: 6371.0171
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1948/4262252040.py in <module>
# ----> 1 hist = model.fit(train_ds, validation_data=val_ds, epochs=100, callbacks=callbacks_list)
#
# ~\anaconda3\envs\landmark\lib\site-packages\tensorflow\python\keras\engine\training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# ~\anaconda3\envs\landmark\lib\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1096                 batch_size=batch_size):
#    1097               callbacks.on_train_batch_begin(step)
# -> 1098               tmp_logs = train_function(iterator)
#    1099               if data_handler.should_sync:
#    1100                 context.async_wait()
#
# ~\anaconda3\envs\landmark\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# ~\anaconda3\envs\landmark\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     805       # In this case we have created variables on the first call, so we run the
#     806       # defunned version which is guaranteed to never create variables.
# --> 807       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     808     elif self._stateful_fn is not None:
#     809       # Release the lock early so that multiple threads can perform the call
#
# ~\anaconda3\envs\landmark\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2827     with self._lock:
#    2828       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2829     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2830
#    2831   @property
#
# ~\anaconda3\envs\landmark\lib\site-packages\tensorflow\python\eager\function.py in _filtered_call(self, args, kwargs, cancellation_manager)
#    1841       `args` and `kwargs`.
#    1842     """
# -> 1843     return self._call_flat(
#    1844         [t for t in nest.flatten((args, kwargs), expand_composites=True)
#    1845          if isinstance(t, (ops.Tensor,
#
# ~\anaconda3\envs\landmark\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1921         and executing_eagerly):
#    1922       # No tape is watching; skip to running the function.
# -> 1923       return self._build_call_outputs(self._inference_function.call(
#    1924           ctx, args, cancellation_manager=cancellation_manager))
#    1925     forward_backward = self._select_forward_and_backward_functions(
#
# ~\anaconda3\envs\landmark\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     543       with _InterpolateFunctionError(self):
#     544         if cancellation_manager is None:
# --> 545           outputs = execute.execute(
#     546               str(self.signature.name),
#     547               num_outputs=self._num_outputs,
#
# ~\anaconda3\envs\landmark\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
plt.figure(figsize=(12, 10))
plt.plot(hist.history['loss'], label='train')
plt.plot(hist.history['val_loss'], label='val')
plt.legend()
plt.title('imagenet weight Loss', size=12)
plt.savefig('./loss_image/None_weight.png')

# %%
df = pd.DataFrame({
    'train_loss': hist.history['loss'],
    'val_loss': hist.history['val_loss']
})
df.to_csv('./loss/detector_None_loss.csv', index=False)
