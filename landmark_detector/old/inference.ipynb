# %%
import tensorflow as tf
import data_util
import cv2
import matplotlib.pyplot as plt
import resnet_V2
from tensorflow.keras.utils import plot_model
from tensorflow import keras

# %%
ds = data_util.get_cu_dataset(train_type='landmark')
ds_size = len(list(ds))
ds_size
# Out:
# 239

# %%
train_size = int(0.7 * ds_size)
val_size = int(0.15 * ds_size)
test_size = int(0.15 * ds_size)

train_ds = ds.take(train_size)
test_ds = ds.skip(train_size)
val_ds = test_ds.skip(val_size)
test_ds = test_ds.take(test_size)

# %%
ae = resnet_V2.ResNetAE()
en = ae.encoder
resnet = keras.models.Sequential()
resnet.add(keras.layers.Input(shape=(256, 256, 3)))
resnet.add(en)
resnet.add(keras.layers.Flatten())
resnet.add(keras.layers.Dense(16))

# %%
resnet.load_weights('./trained_ckpt/multi')
# Out:
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<resnet_V2.ResNetEncoder object at 0x000001DF834ADD60> and <tensorflow.python.keras.layers.core.Flatten object at 0x000001DF8A97AA00>).
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12096/2980551156.py in <module>
# ----> 1 resnet.load_weights('./trained_ckpt/multi')
#
# ~\anaconda3\envs\landmark\lib\site-packages\tensorflow\python\keras\engine\training.py in load_weights(self, filepath, by_name, skip_mismatch, options)
#    2180         save_format = 'h5'
#    2181     if save_format == 'tf':
# -> 2182       status = self._trackable_saver.restore(filepath, options)
#    2183       if by_name:
#    2184         raise NotImplementedError(
#
# ~\anaconda3\envs\landmark\lib\site-packages\tensorflow\python\training\tracking\util.py in restore(self, save_path, options)
#    1317         graph_view=self._graph_view,
#    1318         options=options)
# -> 1319     base.CheckpointPosition(
#    1320         checkpoint=checkpoint, proto_id=0).restore(self._graph_view.root)
#    1321     load_status = CheckpointLoadStatus(
#
# ~\anaconda3\envs\landmark\lib\site-packages\tensorflow\python\training\tracking\base.py in restore(self, trackable)
#     207         # This object's correspondence with a checkpointed object is new, so
#     208         # process deferred restorations for it and its dependencies.
# --> 209         restore_ops = trackable._restore_from_checkpoint_position(self)  # pylint: disable=protected-access
#     210         if restore_ops:
#     211           self._checkpoint.new_restore_ops(restore_ops)
#
# ~\anaconda3\envs\landmark\lib\site-packages\tensorflow\python\training\tracking\base.py in _restore_from_checkpoint_position(self, checkpoint_position)
#     911       python_saveables.extend(new_python_saveables)
#     912     restore_ops.extend(
# --> 913         current_position.checkpoint.restore_saveables(
#     914             tensor_saveables, python_saveables))
#     915     return restore_ops
#
# ~\anaconda3\envs\landmark\lib\site-packages\tensorflow\python\training\tracking\util.py in restore_saveables(self, tensor_saveables, python_saveables)
#     294             ("Saveable keys changed when validating. Got back %s, was "
#     295              "expecting %s") % (tensor_saveables.keys(), validated_names))
# --> 296       new_restore_ops = functional_saver.MultiDeviceSaver(
#     297           validated_saveables).restore(self.save_path_tensor, self.options)
#     298       if not context.executing_eagerly():
#
# ~\anaconda3\envs\landmark\lib\site-packages\tensorflow\python\training\saving\functional_saver.py in restore(self, file_prefix, options)
#     338       restore_ops = tf_function_restore()
#     339     else:
# --> 340       restore_ops = restore_fn()
#     341
#     342     for callback in self._after_restore_callbacks:
#
# ~\anaconda3\envs\landmark\lib\site-packages\tensorflow\python\training\saving\functional_saver.py in restore_fn()
#     314       for device, saver in sorted(self._single_device_savers.items()):
#     315         with ops.device(device):
# --> 316           restore_ops.update(saver.restore(file_prefix, options))
#     317
#     318       return restore_ops
#
# ~\anaconda3\envs\landmark\lib\site-packages\tensorflow\python\training\saving\functional_saver.py in restore(self, file_prefix, options)
#     108     for saveable, restored_tensors in zip(self._saveable_objects,
#     109                                           structured_restored_tensors):
# --> 110       restore_ops[saveable.name] = saveable.restore(
#     111           restored_tensors, restored_shapes=None)
#     112     return restore_ops
#
# ~\anaconda3\envs\landmark\lib\site-packages\tensorflow\python\training\saving\saveable_object_util.py in restore(self, restored_tensors, restored_shapes)
#     124     with ops.device(self._var_device):
#     125       restored_tensor = array_ops.identity(restored_tensor)
# --> 126       return resource_variable_ops.shape_safe_assign_variable_handle(
#     127           self.handle_op, self._var_shape, restored_tensor)
#     128
#
# ~\anaconda3\envs\landmark\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py in shape_safe_assign_variable_handle(handle, shape, value, name)
#     309   with _handle_graph(handle):
#     310     value_tensor = ops.convert_to_tensor(value)
# --> 311   shape.assert_is_compatible_with(value_tensor.shape)
#     312   return gen_resource_variable_ops.assign_variable_op(handle,
#     313                                                       value_tensor,
#
# ~\anaconda3\envs\landmark\lib\site-packages\tensorflow\python\framework\tensor_shape.py in assert_is_compatible_with(self, other)
#    1132     """
#    1133     if not self.is_compatible_with(other):
# -> 1134       raise ValueError("Shapes %s and %s are incompatible" % (self, other))
#    1135
#    1136   def most_specific_compatible_shape(self, other):
#
# ValueError: Shapes (16,) and (133,) are incompatible

# %%
for i in test_ds.take(1):
    sample = i

# %%
sample = sample[0]
sample.shape

# %%
infer = resnet(sample)
infer.shape

# %%
import matplotlib.pyplot as plt
import cv2

# %%
plt.figure(figsize=(16, 16))
for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(sample[i].numpy())
    plt.axis('off')

# %%
plt.figure(figsize=(16, 16))
for i in range(9):
    image = sample[i].numpy()
    labels = infer[i].numpy().reshape(-1, 2)
    
    for l in labels:
        center = [int(l[0]), int(l[1])]
        cv2.circle(image, center=tuple(center), radius=3, color=(0,0,255), thickness=-1, lineType=cv2.LINE_AA)
    ax = plt.subplot(3, 3, i + 1) 
    plt.imshow(image)
    plt.axis('off')
plt.savefig('./train_result/multi_infer.png')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
